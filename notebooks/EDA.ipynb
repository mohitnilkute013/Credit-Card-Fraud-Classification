# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt

# %%
df = pd.read_excel('D:\Data Science\iNeuron\ML\Logistic\Credit Card Fraud Classification\data\default of credit card clients.xls',header=1)

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(), cmap='coolwarm', annot=True)
# Out:
# <Axes: >

# %%
# train_cols = list(train_df.columns)
# num_cols = len(train_cols)
# num_plots_per_row = 5
# num_rows = (num_cols + num_plots_per_row - 1) // num_plots_per_row

# fig, axes = plt.subplots(num_rows, num_plots_per_row, figsize=(15, 4*num_rows))
# axes = axes.flatten()

# for i, col in enumerate(train_cols):
#     sns.boxplot(x=train_df[col], ax=axes[i])
#     axes[i].set_title("Train - {}".format(col))

# # Remove empty subplots if necessary
# if num_cols % num_plots_per_row != 0:
#     for j in range(num_cols, num_rows*num_plots_per_row):
#         fig.delaxes(axes[j])

# plt.tight_layout()
# plt.show()
# Out:
# ID
# LIMIT_BAL
# SEX
# EDUCATION
# MARRIAGE
# AGE
# PAY_0
# PAY_2
# PAY_3
# PAY_4
# PAY_5
# PAY_6
# BILL_AMT1
# BILL_AMT2
# BILL_AMT3
# BILL_AMT4
# BILL_AMT5
# BILL_AMT6
# PAY_AMT1
# PAY_AMT2
# PAY_AMT3
# PAY_AMT4
# PAY_AMT5
# PAY_AMT6
# default payment next month

# %%
numerical_columns = df.drop(['ID', 'default payment next month'], axis=1).columns
numerical_columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6'],
#       dtype='object')

# %%
# Select the numerical columns to plot
# numerical_columns = ['Air temperature [K]', 'Process temperature [K]', 'Rotational speed [rpm]', 'Torque [Nm]', 'Tool wear [min]']
numerical_columns = df.drop(['ID', 'SEX', 'EDUCATION', 'MARRIAGE', 'default payment next month'], axis=1).columns

# Create boxplots for each numerical column
plt.figure(figsize=(15, 15))
for i, column in enumerate(numerical_columns):
    plt.subplot(12, 2, i+1)
    sns.boxplot(data=df[column], orient='h')
    plt.title(f'Boxplot: {column}')
    plt.xlabel(column)
plt.tight_layout()
plt.show()
